# %% [markdown]
# <img src="https://teaching.bowyer.ai/sdsai/0/img/IMPERIAL_logo_RGB_Blue_2024.svg" alt="Imperial Logo" width="500"/><br /><br />
#
# Manipulating and Visualising Data - Worked Examples
# ==============
# ### SURG70098 - Surgical Data Science and AI
# ### Stuart Bowyer

# %% [markdown]
# # Example 2.1
# ## Mean Arterial Pressure Calculator
#
# Write a simple function to compute MAP based on the equation below
# *   MAP = diastolic + (systolic - diastolic) / 3
# *   Test it with 120/80

# %%
# Define the function with your chosen name and parameters


# Call the function with example values and print the result
# For example, for systolic = 120 and diastolic = 80
# calculate_map(120, 80)

# %% [markdown]
# # Example 2.2
# ## Exploring CRP Data
# *   Inspect the data as a dataframe (what are the column types?)
# *   Preview the top of the dataframe
# *   Add a numeric value column
# *   Filter to only view 'elevated' CRP values > 5.0 mg/L

# %%
import pandas as pd

# 1. Load the data
url = 'https://teaching.bowyer.ai/sdsai/1/data/dummy_crp_data.csv'
df_crp = pd.read_csv(url)

# 2. Inspect the raw data

# 3. Create a new numeric column by cleaning the 'crp' string
# We haven't covered this yet - here's a hint:
# df_crp['crp'].str.removesuffix(' mg/L').astype(float)

# 4. Inspect the result to see our new column

# 5. Filter the DataFrame to find "elevated" CRP values (e.g., > 5 mg/L)

# 6. Show the result
